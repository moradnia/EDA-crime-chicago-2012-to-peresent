# %% [markdown]
# <a href="https://colab.research.google.com/github/moradnia/EDA-crime-chicago-2012-to-peresent/blob/main/Crime_EdA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/drive/MyDrive/Crimes_-_2001_to_Present.csv')
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (21) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.shape
# Out:
# (7246503, 22)

# %%
df
# Out:
#                ID Case Number  ...  Longitude                       Location
# 0        11034701    JA366925  ...        NaN                            NaN
# 1        11227287    JB147188  ...        NaN                            NaN
# 2        11227583    JB147595  ...        NaN                            NaN
# 3        11227293    JB147230  ...        NaN                            NaN
# 4        11227634    JB147599  ...        NaN                            NaN
# ...           ...         ...  ...        ...                            ...
# 7246498  11700926    JC279725  ... -87.717040  (41.862830429, -87.717040084)
# 7246499     24560    JC279072  ... -87.659660  (41.864278228, -87.659660218)
# 7246500  11707734    JC287730  ...        NaN                            NaN
# 7246501  11707239    JC287563  ...        NaN                            NaN
# 7246502     24559    JC278908  ... -87.659682  (41.864278357, -87.659682244)
#
# [7246503 rows x 22 columns]

# %%
df_unclean = df.copy()

# %%
df_unclean.shape
# Out:
# (7246503, 22)

# %%
df_unclean.isnull().sum()
# Out:
# ID                           0
# Case Number                  4
# Date                         0
# Block                        0
# IUCR                         0
# Primary Type                 0
# Description                  0
# Location Description      7701
# Arrest                       0
# Domestic                     0
# Beat                         0
# District                    47
# Ward                    614833
# Community Area          613484
# FBI Code                     0
# X Coordinate            102007
# Y Coordinate            102007
# Year                         0
# Updated On                   0
# Latitude                102007
# Longitude               102007
# Location                102007
# dtype: int64

# %%
df_unclean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7246503 entries, 0 to 7246502
# Data columns (total 22 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   ID                    int64
#  1   Case Number           object
#  2   Date                  object
#  3   Block                 object
#  4   IUCR                  object
#  5   Primary Type          object
#  6   Description           object
#  7   Location Description  object
#  8   Arrest                bool
#  9   Domestic              bool
#  10  Beat                  int64
#  11  District              float64
#  12  Ward                  float64
#  13  Community Area        float64
#  14  FBI Code              object
#  15  X Coordinate          float64
#  16  Y Coordinate          float64
#  17  Year                  int64
#  18  Updated On            object
#  19  Latitude              float64
#  20  Longitude             float64
#  21  Location              object
# ...

# %%
df_unclean.corr()
# Out:
#                       ID    Arrest  Domestic  ...      Year  Latitude  Longitude
# ID              1.000000 -0.070305  0.051309  ...  0.986941 -0.002796   0.003933
# Arrest         -0.070305  1.000000 -0.068516  ... -0.071314  0.000178  -0.031415
# Domestic        0.051309 -0.068516  1.000000  ...  0.053324 -0.078147   0.005107
# Beat           -0.038310 -0.016521 -0.043497  ... -0.040105  0.613296  -0.477051
# District       -0.005267 -0.017918 -0.040136  ... -0.006569  0.620971  -0.528799
# Ward            0.020057 -0.017925 -0.053934  ...  0.019515  0.633134  -0.439567
# Community Area -0.010044 -0.002136  0.076440  ... -0.010632 -0.753131   0.241883
# X Coordinate    0.003968 -0.031056  0.006267  ...  0.004814 -0.418683   0.999794
# Y Coordinate   -0.002792  0.000057 -0.078337  ... -0.002822  0.999993  -0.414466
# Year            0.986941 -0.071314  0.053324  ...  1.000000 -0.002831   0.004814
# Latitude       -0.002796  0.000178 -0.078147  ... -0.002831  1.000000  -0.416114
# ...

# %%
df_unclean.head()
# Out:
#          ID Case Number                    Date  ... Latitude Longitude Location
# 0  11034701    JA366925  01/01/2001 11:00:00 AM  ...      NaN       NaN      NaN
# 1  11227287    JB147188  10/08/2017 03:00:00 AM  ...      NaN       NaN      NaN
# 2  11227583    JB147595  03/28/2017 02:00:00 PM  ...      NaN       NaN      NaN
# 3  11227293    JB147230  09/09/2017 08:17:00 PM  ...      NaN       NaN      NaN
# 4  11227634    JB147599  08/26/2017 10:00:00 AM  ...      NaN       NaN      NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# # Null Values

# %%
print("Are There Missing Data? :",df.isnull().any().any())     
print(df.isnull().sum())
# Out:
# Are There Missing Data? : True
# ID                           0
# Case Number                  4
# Date                         0
# Block                        0
# IUCR                         0
# Primary Type                 0
# Description                  0
# Location Description      7701
# Arrest                       0
# Domestic                     0
# Beat                         0
# District                    47
# Ward                    614833
# Community Area          613484
# FBI Code                     0
# X Coordinate            102007
# Y Coordinate            102007
# Year                         0
# Updated On                   0
# Latitude                102007
# Longitude               102007
# Location                102007
# dtype: int64

# %%
dfcrime = df.dropna()
dfcrime.shape
# Out:
# (6532892, 22)

# %%
count_data_origin = df['Date'].count()
count_data_modify = dfcrime['Date'].count()
Value = (count_data_modify/count_data_origin)*100
print('The analysis will be carried on with:',"%.2f" % Value,'% of the total data')
# Out:
# The analysis will be carried on with: 90.15 % of the total data

# %%
dfcrime.info(null_counts = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6532892 entries, 63289 to 7246502
# Data columns (total 22 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   ID                    6532892 non-null  int64
#  1   Case Number           6532892 non-null  object
#  2   Date                  6532892 non-null  object
#  3   Block                 6532892 non-null  object
#  4   IUCR                  6532892 non-null  object
#  5   Primary Type          6532892 non-null  object
#  6   Description           6532892 non-null  object
#  7   Location Description  6532892 non-null  object
#  8   Arrest                6532892 non-null  bool
#  9   Domestic              6532892 non-null  bool
#  10  Beat                  6532892 non-null  int64
#  11  District              6532892 non-null  float64
#  12  Ward                  6532892 non-null  float64
#  13  Community Area        6532892 non-null  float64
# ...

# %%
plt.figure(figsize=(10,7))
sns.heatmap(df[[
        "ID",
        "IUCR",
        "Beat",
        "Case Number",
        "District",
        "Ward",
        "Updated On",
        "Year",
        "Community Area",
        "X Coordinate",
        "Y Coordinate",
        "Latitude",
        "Longitude",
        "Location",
        "FBI Code",
    ]].isnull(), cbar = False, cmap = 'viridis')

# %%
df_unclean.drop(
    [
        "ID",
        "IUCR",
        "Beat",
        "Case Number",
        "District",
        "Ward",
        "Updated On",
        "Year",
        "Community Area",
        "X Coordinate",
        "Y Coordinate",
        "Latitude",
        "Longitude",
        "Location",
        "FBI Code",
    ],
    axis=1,
    inplace=True,
)

# %%
df_unclean.columns
# Out:
# Index(['Date', 'Block', 'Primary Type', 'Description', 'Location Description',
#        'Arrest', 'Domestic'],
#       dtype='object')

# %%
df_unclean.Date = pd.to_datetime(df_unclean.Date, format="%m/%d/%Y %I:%M:%S %p")

df_unclean.set_index("Date", inplace=True)

# %%
df_unclean.head()
# Out:
#                                     Block  ... Domestic
# Date                                       ...
# 2001-01-01 11:00:00       016XX E 86TH PL  ...    False
# 2017-10-08 03:00:00    092XX S RACINE AVE  ...    False
# 2017-03-28 14:00:00       026XX W 79TH ST  ...    False
# 2017-09-09 20:17:00  060XX S EBERHART AVE  ...    False
# 2017-08-26 10:00:00   001XX W RANDOLPH ST  ...    False
#
# [5 rows x 6 columns]

# %% [markdown]
# # Number of cases by type

# %%
import plotly.express as px
def plot_counts(serie, title):
    df = pd.DataFrame(serie.value_counts()[:15])
    df.columns = ["Freq"]
    df["Type"] = df.index
    fig = px.bar(df, y="Freq", x="Type", text="Freq", color="Freq")
    fig.update_traces(texttemplate="%{text:.2s}", textposition="outside")
    # fig.update_layout(uniformtext_minsize=8, uniformtext_mode="hide")
    fig.update_layout(title_text=title)
    fig.show()


plot_counts(df_unclean["Primary Type"], "Kind of Crimes")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ccb5ff76-58fa-4210-88c7-54b2e291d216" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ccb5ff76-58fa-4210-88c7-54b2e291d216")) {
#                     Plotly.newPlot(
#                         'ccb5ff76-58fa-4210-88c7-54b2e291d216',
# ...

# %% [markdown]
# # Location Description

# %%
plot_counts(df_unclean["Location Description"], "Location of Crimes")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a0e967ab-d5b5-4cff-8746-5cfec6ec7205" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a0e967ab-d5b5-4cff-8746-5cfec6ec7205")) {
#                     Plotly.newPlot(
#                         'a0e967ab-d5b5-4cff-8746-5cfec6ec7205',
# ...

# %%
aux = pd.DataFrame(df_unclean.resample("M").size(), columns=["Number of cases"])
aux["Month"] = aux.index.month.astype(str)
aux["Year"] = aux.index.year.astype(str)
aux["Year-Month"] = aux["Year"].str.cat(aux["Month"].str.zfill(2), sep="-")
aux.head()
# Out:
#             Number of cases Month  Year Year-Month
# Date
# 2001-01-31            38105     1  2001    2001-01
# 2001-02-28            33780     2  2001    2001-02
# 2001-03-31            40555     3  2001    2001-03
# 2001-04-30            40084     4  2001    2001-04
# 2001-05-31            41828     5  2001    2001-05

# %% [markdown]
# # Number of cases per Year x months
# By headtmap

# %%
aux_csm = aux[["Month", "Year", "Number of cases"]]
plt.figure(figsize=(25, 10))
sns.heatmap(
    aux_csm.pivot("Month", "Year", "Number of cases").fillna(0).astype(int),
    annot=True,
    fmt="d",
    linewidths=0.5,
    cmap="Reds",
)

# %% [markdown]
# # by Bars

# %%
fig = px.bar(
    aux,
    x="Year-Month",
    y="Number of cases",
    hover_data=["Year", "Month", "Number of cases"],
    color="Number of cases",
    text="Number of cases",
    height=700,
    width=3000,
)
fig.update_traces(texttemplate="%{text:.2s}", textposition="outside")
fig.update_layout(title_text='Crime counts per year-month in bars')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9a7e75a6-2d6b-45ff-bc34-e973b85d6c85" class="plotly-graph-div" style="height:700px; width:3000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9a7e75a6-2d6b-45ff-bc34-e973b85d6c85")) {
#                     Plotly.newPlot(
#                         '9a7e75a6-2d6b-45ff-bc34-e973b85d6c85',
# ...

# %% [markdown]
# # Agregate by Months

# %%
fig = px.bar(
    aux,
    x="Month",
    y="Number of cases",
    hover_data=["Year", "Month", "Number of cases"],
    color="Number of cases",
    text="Number of cases",
    height=600,
    width=1500,
)
fig.update_traces(texttemplate="%{text:.2s}", textposition="outside")
fig.update_layout(title_text="Crime counts per year-month in stacked bars (Month)")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1766ad31-f546-41c0-a904-e3c73d3966bc" class="plotly-graph-div" style="height:600px; width:1500px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1766ad31-f546-41c0-a904-e3c73d3966bc")) {
#                     Plotly.newPlot(
#                         '1766ad31-f546-41c0-a904-e3c73d3966bc',
# ...

# %% [markdown]
# # Agregate by Year

# %%
fig = px.bar(
    aux,
    x="Year",
    y="Number of cases",
    hover_data=["Year", "Month", "Number of cases"],
    color="Number of cases",
    text="Number of cases",
    height=600,
    width=1500,
)
fig.update_traces(texttemplate="%{text:.2s}", textposition="outside")
fig.update_layout(title_text="Crime counts per year-month in stacked bars (Years)")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3fd8db64-61c1-4e54-90fe-e6d018f6eff7" class="plotly-graph-div" style="height:600px; width:1500px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3fd8db64-61c1-4e54-90fe-e6d018f6eff7")) {
#                     Plotly.newPlot(
#                         '3fd8db64-61c1-4e54-90fe-e6d018f6eff7',
# ...

# %% [markdown]
# # Assert and location and etc

# %%
df_2=df.copy()

# %%
df_2 = df_2.dropna()

# %%
df_2
# Out:
#                ID Case Number  ...  Longitude                       Location
# 63289    11665567    JC234307  ... -87.612583     (41.708589, -87.612583094)
# 63374    11667963    JC235212  ... -87.732066  (41.940297617, -87.732066473)
# 63375    11667968    JC237058  ... -87.755230  (41.884865037, -87.755230327)
# 63451    11668309    JC238187  ... -87.613508  (41.697609261, -87.613507612)
# 63855    11692179    JC261724  ... -87.653167  (41.729973132, -87.653166753)
# ...           ...         ...  ...        ...                            ...
# 7246495   9999999    HY189683  ... -87.767226  (41.959943835, -87.767225719)
# 7246496  11700037    JC278815  ... -87.742535  (41.917879493, -87.742535496)
# 7246498  11700926    JC279725  ... -87.717040  (41.862830429, -87.717040084)
# 7246499     24560    JC279072  ... -87.659660  (41.864278228, -87.659660218)
# 7246502     24559    JC278908  ... -87.659682  (41.864278357, -87.659682244)
#
# [6532892 rows x 22 columns]

# %%
import folium

# %%
chicago_map = folium.Map(location=[41.708589, -87.612583094],
                        zoom_start=11,
                        tiles="CartoDB dark_matter")

# %%
locations = df.groupby('Community Area').first()

# %%
new_locations = locations.loc[:, ['Latitude', 'Longitude', 'Location Description', 'Arrest']]

# %%
new_locations.head()
# Out:
#                  Latitude  Longitude               Location Description  Arrest
# Community Area
# 0.0             41.970515 -87.836651  OTHER RAILROAD PROP / TRAIN DEPOT    True
# 1.0             42.012652 -87.673666                           SIDEWALK   False
# 2.0             42.016919 -87.684345                          APARTMENT   False
# 3.0             41.955536 -87.656163                          APARTMENT   False
# 4.0             41.968075 -87.682403                   RESIDENCE-GARAGE   False

# %%
for i in range(len(new_locations)):
    lat = new_locations.iloc[i][0]
    long = new_locations.iloc[i][1]
    popup_text = """Community Index : {}<br>
                Arrest : {}<br>
                Location Description : {}<br>"""
    popup_text = popup_text.format(new_locations.index[i],
                               new_locations.iloc[i][-1],
                               new_locations.iloc[i][-2]
                               )
    folium.CircleMarker(location = [lat, long], popup= popup_text, fill = True).add_to(chicago_map)

# %%
chicago_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
unique_locations = df['Location'].value_counts()

# %%
unique_locations.index
# Out:
# Index(['(41.976290414, -87.905227221)', '(41.754592961, -87.741528537)',
#        '(41.883500187, -87.627876698)', '(41.897895128, -87.624096605)',
#        '(41.896888586, -87.628203192)', '(41.909664252, -87.742728815)',
#        '(41.885487535, -87.726422045)', '(41.788987036, -87.74147999)',
#        '(41.88233367, -87.627841791)', '(41.904192368, -87.647000785)',
#        ...
#        '(41.671342612, -87.627119777)', '(41.877488907, -87.709173495)',
#        '(41.807782428, -87.6079034)', '(41.90277433, -87.702138865)',
#        '(41.84434112, -87.726084393)', '(41.972645584, -87.686482439)',
#        '(41.802374138, -87.595941873)', '(41.909602465, -87.666299983)',
#        '(41.777077412, -87.638664359)', '(41.942671628, -87.699462916)'],
#       dtype='object', length=874120)

# %% [markdown]
# # A simple Criminal Rate Index DataFrame

# %%
CR_index = pd.DataFrame({"Raw_String" : unique_locations.index, "ValueCount":unique_locations})
CR_index.index = range(len(unique_locations))
CR_index.head()
# Out:
#                       Raw_String  ValueCount
# 0  (41.976290414, -87.905227221)       13615
# 1  (41.754592961, -87.741528537)        9857
# 2  (41.883500187, -87.627876698)        7744
# 3  (41.897895128, -87.624096605)        4727
# 4  (41.896888586, -87.628203192)        3311

# %%
def Location_extractor(Raw_Str):
    preProcess = Raw_Str[1:-1].split(',')
    lat =  float(preProcess[0])
    long = float(preProcess[1])
    return (lat, long)

# %%
CR_index['LocationCoord'] = CR_index['Raw_String'].apply(Location_extractor)

# %%
CR_index  = CR_index.drop(columns=['Raw_String'], axis = 1)

# %% [markdown]
# # A Simple Chicago Mapping showing the total criminal rates

# %%
# %%time

chicago_map_crime = folium.Map(location=[41.895140898, -87.624255632],
                        zoom_start=13,
                        tiles="CartoDB dark_matter")

for i in range(500):
    lat = CR_index['LocationCoord'].iloc[i][0]
    long = CR_index['LocationCoord'].iloc[i][1]
    radius = CR_index['ValueCount'].iloc[i] / 45
    
    if CR_index['ValueCount'].iloc[i] > 1000:
        color = "#FF4500"
    else:
        color = "#008080"
    
    popup_text = """Latitude : {}<br>
                Longitude : {}<br>
                Criminal Incidents : {}<br>"""
    popup_text = popup_text.format(lat,
                               long,
                               CR_index['ValueCount'].iloc[i]
                               )
    folium.CircleMarker(location = [lat, long], popup= popup_text,radius = radius, color = color, fill = True).add_to(chicago_map_crime)
# Out:
# CPU times: user 128 ms, sys: 13.9 ms, total: 142 ms
# Wall time: 145 ms

# %%
chicago_map_crime
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df['Primary Type'].value_counts().plot.bar(figsize=(20,15))
plt.title("Crimes")
plt.show()

# %%
x_theft = df[df['Primary Type'] == "THEFT"]
x_battery = df[df['Primary Type'] == "BATTERY"]
x_cd = df[df['Primary Type'] == "CRIMINAL DAMAGE"]
x_narc = df[(df['Primary Type'] == "NARCOTICS")]

# %%
df[df['Primary Type']=='DOMESTIC VIOLENCE']
# Out:
#               ID Case Number  ... Longitude                      Location
# 1550501  1326195     G021609  ... -87.55432  (41.73617608, -87.554319607)
#
# [1 rows x 22 columns]

# %%
x_theft['Description'].value_counts(normalize=True).plot.barh(figsize=(15,8))
plt.title("Theft Types")
plt.show()

# %%
x_battery['Description'].value_counts(normalize=True).plot.barh(figsize=(25,15))
plt.title("Battery Types")
plt.show()

# %%
x_cd['Description'].value_counts(normalize=True).plot.bar()
plt.title("Criminal Damage Types")
plt.show()

# %%
x_narc['Description'].value_counts(normalize=True).plot.barh(figsize=(20,15))
plt.title("Narcotics Types")
plt.show()
